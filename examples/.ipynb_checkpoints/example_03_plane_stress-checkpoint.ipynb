# %% [markdown]
# # Plane stress example

# %% [markdown]
# ### Preamble

# %% [markdown]
# - Include the necesary modules from Julia's standard repositories.

# %%
# using Distributed
# using Statistics
using LinearAlgebra
using Printf, WriteVTK, AbaqusReader, Logging
using PyCall, PyPlot, FileIO, ProgressMeter

# %%
using AD4SM
# Out:
# ┌ Info: Precompiling AD4SM [7861f83d-ce22-4070-aa20-44578e274a9b]
# └ @ Base loading.jl:1342

# %% [markdown]
# A few helper functions

# %%
mean(x) = sum(x)/length(x)

# this function is the constraint equation for the internal holes
function cnst_func(u,ucntr,r0,cntr0,Rsq) 
    r    = r0+u
    cntr = cntr0+ucntr
    sum((r-cntr).^2)-Rsq
end
# this function find the centre of the constrained holes in the reference configuration
function find_centre(nodes; dTol = 1e-12, maxiter=21)

  c0    = mean(nodes)
  bdone = false  
  iter  = 0

  while !bdone
    D2c0   = adiff.D2(c0)
    global deltas = [(D2c0[1]-p[1]).^2+(D2c0[2]-p[2]).^2 for p in nodes]
    r      = norm(deltas)
    grad   = adiff.grad(r)
    if (norm(grad)<dTol) || (iter>maxiter)
      bdone = true
    else
      c0  -= adiff.hess(r)\grad
    end
    iter +=1
  end
  Rsquares = adiff.val.(deltas) 
  return (c0, Rsquares)
end
    
# some plotting functions
patch = pyimport("matplotlib.patches")
coll  = pyimport("matplotlib.collections")  

function plot_model(elems, nodes; 
                    u = zeros(length(nodes[1]), length(nodes)),
                    Φ = [],
                    linewidth = 0.25,
                    facecolor = :c,
                    edgecolor = :b, 
                    alpha     = 1,
                    cmap      = :hsv,
                    clim      = [],
                    dTol      = 1e-6,
                    cfig      = figure(),
                    ax        = cfig.add_subplot(1,1,1))

  nodes     = [node + u[:,ii] for (ii,node) in enumerate(nodes)]
  patchcoll = coll.PatchCollection([patch.Polygon(nodes[elem.nodes]) 
                                    for elem ∈ elems], cmap=cmap)
  if !isempty(Φ)
    patchcoll.set_array(Φ)
    cfig.colorbar.(patchcoll, ax=ax)

    if isempty(clim)
      clim = patchcoll.get_clim()
      if abs(clim[2]-clim[1]) < dTol
        clim  = sum(clim)/2*[0.9, 1.1]
      end
    end
    patchcoll.set_clim(clim)
  else
    patchcoll.set_color(facecolor)
  end

  patchcoll.set_edgecolor(edgecolor)
  patchcoll.set_alpha(alpha)
  patchcoll.set_linewidth(linewidth)

  ax.set_aspect("equal")
  ax.add_collection(patchcoll)
  ax.autoscale()
  return (cfig, ax, patchcoll)
end
function get_I1(elems, u0)
      
    nElems = length(elems)
    F      = Elements.getinfo(elems,u0,info=:F)
    J      = [det(F)                       for F  in F]
    C      = [transpose(F)*F               for F  in F]
    L3     = [(C[1]C[4]-C[2]C[3])^-1       for C  in C]
    Ic     = [Materials.getInvariants(C[ii], L3[ii]) for ii in 1:nElems] 

    I1     = [item[1] for item in Ic]
end 
;

# %% [markdown]
# A few parameters controlling the simulation, file naming, output produced etc, are set

# %%
sMeshFile = "Pattern2D03FinerMesh02j.inp"
ϵn0       = 0.24
bfside    = true
mat       = Materials.NeoHooke(10.0)
bprogress = false
bwarmup   = true
blheqs    = false
bsheqs    = true
sFileName = splitext(sMeshFile)[1]
;

# %% [markdown]
# Load the mesh and store node sets

# %%
mymodel   = with_logger(Logging.NullLogger()) do
  AbaqusReader.abaqus_read_mesh(sMeshFile)
end
@printf("\n\t loaded %s \n", sMeshFile)

(xmin, xmax) = extrema([item[2][1] for item ∈ mymodel["nodes"]])
(ymin, ymax) = extrema([item[2][2] for item ∈ mymodel["nodes"]])

nodes    = [mymodel["nodes"][ii]    for ii ∈ 1:length(mymodel["nodes"])]
el_nodes = [mymodel["elements"][ii] for ii ∈ 1:length(mymodel["elements"])]

elems = [
    if length(item)==3
      Elements.Tria(item, nodes[item], mat=mat)
    elseif length(item)==4
      Elements.Quad(item, nodes[item], mat=mat)
  end for item ∈ el_nodes]

points   = hcat(nodes...)
cells    = [if length(nodes)==3
            MeshCell(VTKCellTypes.VTK_TRIANGLE, nodes)
          else length(nodes)==4
            MeshCell(VTKCellTypes.VTK_QUAD, nodes)
          end  for nodes in el_nodes ]

@show nNodes, nElems  = length(nodes), length(el_nodes)
@show Δx, Δy          = (xmax-xmin), (ymax-ymin)

nid_bndl = mymodel["node_sets"]["ID_L"]
nid_bndr = mymodel["node_sets"]["ID_R"]
nid_bndt = mymodel["node_sets"]["ID_T"]
nid_bndb = mymodel["node_sets"]["ID_B"]

nid_sh01 = mymodel["node_sets"]["ID_SH01"]
nid_sh02 = mymodel["node_sets"]["ID_SH02"]
nid_sh03 = mymodel["node_sets"]["ID_SH03"]
nid_sh04 = mymodel["node_sets"]["ID_SH04"]
nid_sh05 = mymodel["node_sets"]["ID_SH05"]
nid_sh06 = mymodel["node_sets"]["ID_SH06"]
nid_sh07 = mymodel["node_sets"]["ID_SH07"]
nid_sh08 = mymodel["node_sets"]["ID_SH08"]
nid_sh09 = mymodel["node_sets"]["ID_SH09"]

nid_shx  = [nid_sh01, nid_sh02, nid_sh03,
          nid_sh04, nid_sh05, nid_sh06,
          nid_sh07, nid_sh08, nid_sh09]
nSHs     = length(nid_shx)

nid_lh01 = mymodel["node_sets"]["ID_LH01"]
nid_lh02 = mymodel["node_sets"]["ID_LH02"]
nid_lh03 = mymodel["node_sets"]["ID_LH03"]
nid_lh04 = mymodel["node_sets"]["ID_LH04"]
nid_lh05 = mymodel["node_sets"]["ID_LH05"]
nid_lh06 = mymodel["node_sets"]["ID_LH06"]
nid_lh07 = mymodel["node_sets"]["ID_LH07"]
nid_lh08 = mymodel["node_sets"]["ID_LH08"]
nid_lh09 = mymodel["node_sets"]["ID_LH09"]
nid_lh10 = mymodel["node_sets"]["ID_LH10"]
nid_lh11 = mymodel["node_sets"]["ID_LH11"]
nid_lh12 = mymodel["node_sets"]["ID_LH12"]
nid_lh13 = mymodel["node_sets"]["ID_LH13"]
nid_lh14 = mymodel["node_sets"]["ID_LH14"]
nid_lh15 = mymodel["node_sets"]["ID_LH15"]
nid_lh16 = mymodel["node_sets"]["ID_LH16"]

nid_lhx  = [nid_lh01, nid_lh02, nid_lh03,
          nid_lh04, nid_lh05, nid_lh06,
          nid_lh07, nid_lh08, nid_lh09, nid_lh10,
          nid_lh11, nid_lh12, nid_lh13,
          nid_lh14, nid_lh15, nid_lh16]
nLHs     = length(nid_lhx)

cntrs_s = [find_centre(nodes[idx]) for idx in nid_shx]
cntrs_l = [find_centre(nodes[idx]) for idx in nid_lhx]
nodes = vcat(nodes,getindex.(cntrs_s,1),getindex.(cntrs_l,1))
;
# Out:
# 	 loaded Pattern2D03FinerMesh02j.inp
# (nNodes, nElems) = (length(nodes), length(el_nodes)) = (11678, 10832)
# (Δx, Δy) = (xmax - xmin, ymax - ymin) = (20.0, 20.0)

# %%
plot_model(elems, nodes, facecolor=:c, edgecolor=:c)
PyPlot.title("undeformed model")
;
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# sys:1: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# Write constraint equations for the holes:
#  - if bsheqs is true equations are added for the smaller holes
#  - if blheqs is true equations are added for the larger holes

# %%
idxs  = LinearIndices(((2, nNodes+nSHs+nLHs)))
eqns  = Array{Solvers.ConstEq}(undef, 0)
if bsheqs
    eqns  = vcat(eqns,
                 [ [ begin
                      r0      = nodes[nid]
                      cntr0   = nodes[nNodes+ii]
                      Rsq     = cntrs_s[ii][2][jj]
                      id_dofs = vcat(idxs[:,nid][:],idxs[:,nNodes+ii][:])
                      Solvers.ConstEq(x->cnst_func(x[1:2],x[3:4],r0,cntr0,Rsq), 
                                       id_dofs,adiff.D2) 
                    end  for (jj,nid) in enumerate(nid_ii)] 
                  for (ii,nid_ii) in enumerate(nid_shx)]...)
end
if blheqs
    eqns = vcat(eqns,
                [ [ begin
                     r0      = nodes[nid]
                     cntr0   = nodes[nNodes+nSHs+ii]
                     Rsq     = cntrs_l[ii][2][jj]
                     id_dofs = vcat(idxs[:,nid][:],idxs[:,nNodes+nSHs+ii][:])
                     Solvers.ConstEq(x->cnst_func(x[1:2],x[3:4],r0,cntr0,Rsq), 
                                      id_dofs,adiff.D2) 
                   end  for (jj,nid) in enumerate(nid_ii)] 
                 for (ii,nid_ii) in enumerate(nid_lhx)]... )
end
;

# %% [markdown]
# prepare a few arrays needed to start the solution
# - u is the displacement vector, it contains the boundary conditions,
# - ifree is an array of boolean with the same dimension of u, if ifree is true that DoFs is free, otherwise it is constrained, and the value of the constraint is stored in u

# %% [markdown]
# ### Do the compressive branch

# %% [markdown]
# - initialize the displacement vector and the boundary conditions: u is the array with the DoFs, the NaN entries in u are free DoFs, the !NaN entries are the boundary conditions

# %%
u                  = fill(NaN, 2, nNodes+nSHs+nLHs)
u[:,nid_bndb]     .= 0
u[1,nid_bndt]     .= 0 
u[2,nid_bndt]     .= -ϵn0*Δy

if !bsheqs u[:,nNodes+1:nNodes+nSHs] .= NaN; end
if !blheqs u[:,nNodes+nSHs+1:end]    .= NaN; end

if !bfside
    u[1,nid_bndl] .= 0 
    u[1,nid_bndr] .= 0 
end

ifree     = isnan.(u)
icnst     = .!ifree
;

# %% [markdown]
# - this is a preliminary step, for making sure all constranints are initially satisfied and avoid non-convergence on the first step, the result is used as initial condition for the simulation

# %%
u0         = 1e-4Δx*randn(2, nNodes+nSHs+nLHs)
u0[icnst] .= 0
unew       = copy(u0)
@time Solvers.solvestep!(elems, u0, unew, ifree, eqns=eqns, λ = zeros(length(eqns)),
                          bprogress=false, becho=true)
u[ifree] .= unew[ifree]
;
# Out:
# predictor step done in 10.07 sec., with normupdt: 1.00e-02, starting corrector loop
# iter:  0, norm0: 9.17e-03, normru: 4.53e-01, normre: 3.14e-02, normupdt: 3.00e-02, α: -0.906, eltime: 1.97 sec.
# iter:  1, norm0: 4.89e-04, normru: 4.14e-01, normre: 2.56e-04, normupdt: 1.55e-02, α: -0.819, eltime: 2.12 sec.
# iter:  2, norm0: 2.40e-06, normru: 2.66e-06, normre: 5.74e-06, eltime: 0.50 sec.
#  19.705667 seconds (44.72 M allocations: 6.293 GiB, 8.49% gc time, 23.43% compilation time)

# %% [markdown]
# ### Do the compressive branch

# %%
N       = 24
LF_c    = vcat(range(0.0, 0.9, length=2N÷8),
               range(0.9, 1.0, length=6N÷8))

allus_c = Solvers.solve(elems, u, LF=LF_c, ifree=ifree, eqns=eqns,
                          bprogress=false, becho=true, bechoi=true)
;
# Out:
# predictor step done in 1.76 sec., with normupdt: 0.00e+00, starting corrector loop
# iter:  0, norm0: 0.00e+00, normru: 0.00e+00, normre: 0.00e+00, eltime: 0.46 sec.
# step   1/24, LF=0.000, done in  1 iter, after 2.22 sec.
#
# predictor step done in 2.09 sec., with normupdt: 8.65e-01, starting corrector loop
# iter:  0, norm0: 1.17e-02, normru: 7.45e-02, normre: 1.36e-03, normupdt: 1.08e-02, α:  0.093, eltime: 2.02 sec.
# iter:  1, norm0: 1.17e-02, normru: 1.05e-04, normre: 6.90e-06, normupdt: 2.64e-04, α:  0.536, eltime: 2.07 sec.
# iter:  2, norm0: 1.17e-02, normru: 5.44e-08, normre: 1.03e-07, eltime: 0.48 sec.
# step   2/24, LF=0.180, done in  3 iter, after 6.66 sec.
#
# predictor step done in 1.87 sec., with normupdt: 8.67e-01, starting corrector loop
# iter:  0, norm0: 2.48e-02, normru: 4.08e-02, normre: 1.78e-03, normupdt: 1.36e-02, α:  0.107, eltime: 1.84 sec.
# iter:  1, norm0: 2.49e-02, normru: 7.28e-05, normre: 1.07e-05, normupdt: 4.01e-04, α:  0.506, eltime: 1.88 sec.
# iter:  2, norm0: 2.49e-02, normru: 6.81e-08, normre: 2.73e-07, eltime: 0.60 sec.
# step   3/24, LF=0.360, done in  3 iter, after 6.20 sec.
#
# predictor step done in 1.89 sec., with normupdt: 8.69e-01, starting corrector loop
# iter:  0, norm0: 3.97e-02, normru: 3.04e-02, normre: 2.39e-03, normupdt: 1.87e-02, α:  0.125, eltime: 1.90 sec.
# iter:  1, norm0: 3.97e-02, normru: 7.39e-05, normre: 1.75e-05, normupdt: 6.72e-04, α:  0.437, eltime: 2.02 sec.
# iter:  2, norm0: 3.97e-02, normru: 1.51e-07, normre: 8.23e-07, eltime: 0.48 sec.
# step   4/24, LF=0.540, done in  3 iter, after 6.29 sec.
#
# predictor step done in 1.86 sec., with normupdt: 8.73e-01, starting corrector loop
# iter:  0, norm0: 5.67e-02, normru: 2.58e-02, normre: 3.40e-03, normupdt: 2.65e-02, α:  0.147, eltime: 1.89 sec.
# iter:  1, norm0: 5.65e-02, normru: 1.05e-04, normre: 3.15e-05, normupdt: 1.89e-03, α:  0.318, eltime: 1.87 sec.
# iter:  2, norm0: 5.65e-02, normru: 8.31e-07, normre: 3.22e-06, eltime: 0.62 sec.
# step   5/24, LF=0.720, done in  3 iter, after 6.24 sec.
#
# predictor step done in 1.91 sec., with normupdt: 8.79e-01, starting corrector loop
# iter:  0, norm0: 7.59e-02, normru: 2.39e-02, normre: 5.17e-03, normupdt: 4.00e-02, α:  0.176, eltime: 1.93 sec.
# iter:  1, norm0: 7.53e-02, normru: 2.57e-04, normre: 7.65e-05, normupdt: 1.06e-02, α:  0.124, eltime: 2.02 sec.
# iter:  2, norm0: 7.53e-02, normru: 1.73e-05, normre: 2.71e-05, normupdt: 1.80e-04, α:  0.852, eltime: 2.00 sec.
# iter:  3, norm0: 7.53e-02, normru: 2.24e-08, normre: 1.02e-09, eltime: 0.49 sec.
# step   6/24, LF=0.900, done in  4 iter, after 8.36 sec.
#
# predictor step done in 1.94 sec., with normupdt: 6.65e-07, starting corrector loop
# iter:  0, norm0: 7.53e-02, normru: 4.52e-08, normre: 2.04e-09, eltime: 0.52 sec.
# step   7/24, LF=0.900, done in  1 iter, after 2.46 sec.
#
# predictor step done in 1.92 sec., with normupdt: 2.92e-02, starting corrector loop
# iter:  0, norm0: 7.59e-02, normru: 8.63e-04, normre: 1.08e-05, normupdt: 4.96e-04, α:  0.203, eltime: 1.97 sec.
# iter:  1, norm0: 7.59e-02, normru: 5.25e-08, normre: 5.33e-09, eltime: 0.68 sec.
# step   8/24, LF=0.906, done in  2 iter, after 4.58 sec.
#
# predictor step done in 1.90 sec., with normupdt: 2.92e-02, starting corrector loop
# iter:  0, norm0: 7.65e-02, normru: 8.62e-04, normre: 1.17e-05, normupdt: 7.90e-04, α:  0.207, eltime: 1.90 sec.
# iter:  1, norm0: 7.65e-02, normru: 8.59e-08, normre: 1.23e-08, eltime: 0.49 sec.
# step   9/24, LF=0.912, done in  2 iter, after 4.29 sec.
#
# predictor step done in 2.14 sec., with normupdt: 2.93e-02, starting corrector loop
# iter:  0, norm0: 7.72e-02, normru: 8.61e-04, normre: 1.30e-05, normupdt: 1.33e-03, α:  0.217, eltime: 2.05 sec.
# iter:  1, norm0: 7.72e-02, normru: 1.48e-07, normre: 3.09e-08, eltime: 0.47 sec.
# step  10/24, LF=0.918, done in  2 iter, after 4.67 sec.
#
# predictor step done in 2.09 sec., with normupdt: 2.95e-02, starting corrector loop
# iter:  0, norm0: 7.78e-02, normru: 8.62e-04, normre: 1.53e-05, normupdt: 2.56e-03, α:  0.245, eltime: 2.05 sec.
# iter:  1, norm0: 7.78e-02, normru: 3.05e-07, normre: 1.00e-07, eltime: 0.50 sec.
# step  11/24, LF=0.924, done in  2 iter, after 4.64 sec.
#
# predictor step done in 2.37 sec., with normupdt: 2.97e-02, starting corrector loop
# iter:  0, norm0: 7.85e-02, normru: 8.68e-04, normre: 2.00e-05, normupdt: 5.86e-03, α:  0.342, eltime: 2.16 sec.
# iter:  1, norm0: 7.85e-02, normru: 9.66e-07, normre: 4.76e-07, eltime: 0.47 sec.
# step  12/24, LF=0.929, done in  2 iter, after 5.00 sec.
#
# predictor step done in 2.24 sec., with normupdt: 3.45e-02, starting corrector loop
# iter:  0, norm0: 7.91e-02, normru: 8.95e-04, normre: 3.33e-05, normupdt: 1.80e-02, α:  0.627, eltime: 2.13 sec.
# iter:  1, norm0: 7.91e-02, normru: 7.21e-06, normre: 4.16e-06, eltime: 0.52 sec.
# step  13/24, LF=0.935, done in  2 iter, after 4.89 sec.
#
# predictor step done in 2.18 sec., with normupdt: 7.84e-02, starting corrector loop
# iter:  0, norm0: 7.97e-02, normru: 1.12e-03, normre: 1.17e-04, normupdt: 7.62e-02, α:  0.917, eltime: 2.20 sec.
# iter:  1, norm0: 7.96e-02, normru: 1.16e-04, normre: 7.10e-05, normupdt: 6.43e-02, α:  0.980, eltime: 2.25 sec.
# iter:  2, norm0: 7.96e-02, normru: 8.35e-05, normre: 5.54e-05, normupdt: 3.82e-02, α:  1.000, eltime: 1.96 sec.
# iter:  3, norm0: 7.95e-02, normru: 2.93e-05, normre: 1.83e-05, normupdt: 2.17e-02, α:  1.000, eltime: 2.01 sec.
# iter:  4, norm0: 7.95e-02, normru: 9.52e-06, normre: 5.94e-06, eltime: 0.50 sec.
# step  14/24, LF=0.941, done in  5 iter, after 11.11 sec.
#
# predictor step done in 1.93 sec., with normupdt: 8.42e-01, starting corrector loop
# iter:  0, norm0: 7.97e-02, normru: 1.41e-02, normre: 9.01e-03, normupdt: 8.10e-02, α: -0.383, eltime: 2.18 sec.
# iter:  1, norm0: 7.80e-02, normru: 5.83e-03, normre: 1.21e-04, normupdt: 2.14e-01, α:  0.320, eltime: 1.88 sec.
# iter:  2, norm0: 7.86e-02, normru: 1.89e-03, normre: 6.34e-04, normupdt: 1.02e-01, α: -0.983, eltime: 2.03 sec.
# iter:  3, norm0: 7.84e-02, normru: 1.37e-03, normre: 1.77e-04, normupdt: 2.06e-01, α:  0.982, eltime: 1.95 sec.
# iter:  4, norm0: 7.79e-02, normru: 9.60e-04, normre: 6.03e-04, normupdt: 3.54e-02, α:  0.990, eltime: 2.03 sec.
# iter:  5, norm0: 7.77e-02, normru: 5.47e-05, normre: 2.08e-05, normupdt: 6.47e-02, α:  0.994, eltime: 1.91 sec.
# iter:  6, norm0: 7.74e-02, normru: 1.33e-04, normre: 6.07e-05, normupdt: 2.34e-03, α: -0.992, eltime: 1.90 sec.
# iter:  7, norm0: 7.74e-02, normru: 6.79e-07, normre: 7.12e-08, eltime: 0.48 sec.
# step  15/24, LF=0.947, done in  8 iter, after 16.30 sec.
#
# predictor step done in 1.99 sec., with normupdt: 4.91e-01, starting corrector loop
# iter:  0, norm0: 7.65e-02, normru: 7.14e-03, normre: 3.37e-03, normupdt: 4.81e-02, α: -0.536, eltime: 1.90 sec.
# iter:  1, norm0: 7.63e-02, normru: 9.20e-04, normre: 3.76e-05, normupdt: 1.06e-01, α:  0.502, eltime: 2.08 sec.
# iter:  2, norm0: 7.68e-02, normru: 5.02e-04, normre: 1.74e-04, normupdt: 1.80e-02, α: -0.993, eltime: 2.10 sec.
# iter:  3, norm0: 7.67e-02, normru: 5.55e-05, normre: 5.07e-06, normupdt: 8.35e-03, α:  0.997, eltime: 1.90 sec.
# iter:  4, norm0: 7.66e-02, normru: 6.91e-06, normre: 1.07e-06, eltime: 0.47 sec.
# step  16/24, LF=0.953, done in  5 iter, after 10.43 sec.
#
# predictor step done in 1.95 sec., with normupdt: 2.84e-01, starting corrector loop
# iter:  0, norm0: 7.61e-02, normru: 3.60e-03, normre: 1.16e-03, normupdt: 2.55e-02, α: -0.442, eltime: 1.89 sec.
# iter:  1, norm0: 7.61e-02, normru: 1.31e-04, normre: 9.51e-06, normupdt: 1.48e-02, α:  0.410, eltime: 1.96 sec.
# iter:  2, norm0: 7.61e-02, normru: 1.06e-05, normre: 3.45e-06, normupdt: 2.90e-04, α: -0.975, eltime: 2.10 sec.
# iter:  3, norm0: 7.61e-02, normru: 3.42e-08, normre: 1.17e-09, eltime: 0.48 sec.
# step  17/24, LF=0.959, done in  4 iter, after 8.38 sec.
#
# predictor step done in 2.18 sec., with normupdt: 2.13e-01, starting corrector loop
# iter:  0, norm0: 7.58e-02, normru: 2.60e-03, normre: 6.84e-04, normupdt: 1.65e-02, α: -0.352, eltime: 2.03 sec.
# iter:  1, norm0: 7.58e-02, normru: 4.76e-05, normre: 3.96e-06, normupdt: 4.98e-03, α:  0.313, eltime: 2.08 sec.
# iter:  2, norm0: 7.58e-02, normru: 1.86e-06, normre: 3.87e-07, eltime: 0.48 sec.
# step  18/24, LF=0.965, done in  3 iter, after 6.77 sec.
#
# predictor step done in 1.86 sec., with normupdt: 1.75e-01, starting corrector loop
# iter:  0, norm0: 7.55e-02, normru: 2.09e-03, normre: 4.82e-04, normupdt: 1.13e-02, α: -0.273, eltime: 1.89 sec.
# iter:  1, norm0: 7.55e-02, normru: 2.30e-05, normre: 1.87e-06, normupdt: 2.07e-03, α:  0.227, eltime: 1.94 sec.
# iter:  2, norm0: 7.56e-02, normru: 4.36e-07, normre: 6.59e-08, eltime: 0.63 sec.
# step  19/24, LF=0.971, done in  3 iter, after 6.33 sec.
#
# predictor step done in 1.92 sec., with normupdt: 1.52e-01, starting corrector loop
# iter:  0, norm0: 7.54e-02, normru: 1.78e-03, normre: 3.69e-04, normupdt: 8.38e-03, α: -0.214, eltime: 1.97 sec.
# iter:  1, norm0: 7.54e-02, normru: 1.31e-05, normre: 1.02e-06, normupdt: 1.04e-03, α:  0.161, eltime: 2.04 sec.
# iter:  2, norm0: 7.54e-02, normru: 1.42e-07, normre: 1.61e-08, eltime: 0.46 sec.
# step  20/24, LF=0.976, done in  3 iter, after 6.40 sec.
#
# predictor step done in 1.85 sec., with normupdt: 1.35e-01, starting corrector loop
# iter:  0, norm0: 7.52e-02, normru: 1.57e-03, normre: 2.99e-04, normupdt: 6.53e-03, α: -0.169, eltime: 1.91 sec.
# iter:  1, norm0: 7.52e-02, normru: 8.68e-06, normre: 6.09e-07, eltime: 0.50 sec.
# step  21/24, LF=0.982, done in  2 iter, after 4.26 sec.
#
# predictor step done in 1.89 sec., with normupdt: 1.24e-01, starting corrector loop
# iter:  0, norm0: 7.51e-02, normru: 1.43e-03, normre: 2.55e-04, normupdt: 6.28e-03, α: -0.166, eltime: 2.16 sec.
# iter:  1, norm0: 7.51e-02, normru: 6.05e-06, normre: 4.86e-07, eltime: 0.50 sec.
# step  22/24, LF=0.988, done in  2 iter, after 4.55 sec.
#
# predictor step done in 1.86 sec., with normupdt: 1.16e-01, starting corrector loop
# iter:  0, norm0: 7.50e-02, normru: 1.32e-03, normre: 2.20e-04, normupdt: 5.66e-03, α: -0.133, eltime: 2.02 sec.
# iter:  1, norm0: 7.50e-02, normru: 5.57e-06, normre: 3.53e-07, eltime: 0.48 sec.
# step  23/24, LF=0.994, done in  2 iter, after 4.37 sec.
#
# predictor step done in 1.84 sec., with normupdt: 1.11e-01, starting corrector loop
# iter:  0, norm0: 7.49e-02, normru: 1.23e-03, normre: 1.96e-04, normupdt: 5.76e-03, α: -0.095, eltime: 2.03 sec.
# iter:  1, norm0: 7.49e-02, normru: 6.10e-06, normre: 2.94e-07, eltime: 0.47 sec.
# step  24/24, LF=1.000, done in  2 iter, after 4.34 sec.
# completed in 2 minutes, 29 seconds

# %%
rf_tot_c = [sum(item[2][2,nid_bndt])   for item in allus_c]
Δu_tot_c = [mean(item[1][2,nid_bndt])  for item in allus_c]
;

# %% [markdown]
# - plot the results

# %%
I1 = get_I1(elems, allus_c[end][1])

cfig = figure()
ax1   = cfig.add_subplot(2,1,1)

plot_model(elems, nodes, alpha=0.05, 
  facecolor=:c, edgecolor=:c, cfig=cfig, ax=ax1)
plot_model(elems, nodes, u = allus_c[end][1], 
  edgecolor=:c, Φ = get_I1(elems, allus_c[end][1]), cfig=cfig, ax=ax1)
title("deformed model - compression")

ax2   = cfig.add_subplot(2,1,2)
ax2.plot(Δu_tot_c, rf_tot_c)
xlabel("Δu_tot_")
ylabel("rf_tot_c")
title("force-displacement, compressive branch")

cfig.tight_layout(pad=2.0, w_pad=2.0, h_pad=2.0)
;
# Out:
# Figure(PyObject <Figure size 640x480 with 3 Axes>)

# %% [markdown]
# ### Do the tensile branch

# %%
u                  = fill(NaN, 2, nNodes+nSHs+nLHs)
u[:,nid_bndb]     .= 0
u[1,nid_bndt]     .= 0 
u[2,nid_bndt]     .= ϵn0*Δy

if !bsheqs u[:,nNodes+1:nNodes+nSHs] .= NaN; end
if !blheqs u[:,nNodes+nSHs+1:end]    .= NaN; end

if !bfside
    u[1,nid_bndl]     .= 0 
    u[1,nid_bndr]     .= 0 
end

ifree     = isnan.(u)
icnst     = .!ifree
;

# %%
u0         = 1e-4Δx*randn(2, nNodes+nSHs+nLHs)
u0[icnst] .= 0
unew       = copy(u0)
@time Solvers.solvestep!(elems, u0, unew, ifree, eqns=eqns, λ = zeros(length(eqns)),
                          bprogress=false, becho=true)
u[ifree] .= unew[ifree]
;
# Out:
# predictor step done in 7.68 sec., with normupdt: 1.01e-02, starting corrector loop
# iter:  0, norm0: 8.73e-03, normru: 4.74e-01, normre: 3.36e-02, normupdt: 3.01e-02, α: -0.909, eltime: 7.50 sec.
# iter:  1, norm0: 4.64e-04, normru: 4.33e-01, normre: 3.22e-04, normupdt: 1.53e-02, α: -0.806, eltime: 7.33 sec.
# iter:  2, norm0: 2.41e-06, normru: 2.52e-06, normre: 4.05e-06, eltime: 6.21 sec.
#  28.728233 seconds (16.09 M allocations: 53.957 GiB, 19.31% gc time)

# %%
N       = 10
LF_t    = vcat(range(0.0, 0.9, length=2N÷3),
               range(0.9, 1.0, length=N÷3+1))
println("\n\t starting the tensile branch \n"); flush(stdout)
allus_t = Solvers.solve(elems, u, LF=LF_t, ifree=ifree, eqns=eqns,
                          bprogress=false, becho=true, bechoi=true)
;
# Out:
# 	 starting the tensile branch
#
#
# predictor step done in 8.40 sec., with normupdt: 0.00e+00, starting corrector loop
# iter:  0, norm0: 0.00e+00, normru: 0.00e+00, normre: 0.00e+00, eltime: 7.43 sec.
# step   1/10, LF=0.000, done in  1 iter, after 15.83 sec.
#
# predictor step done in 7.99 sec., with normupdt: 8.65e-01, starting corrector loop
# iter:  0, norm0: 1.06e-02, normru: 7.49e-02, normre: 1.36e-03, normupdt: 9.60e-03, α:  0.080, eltime: 7.73 sec.
# iter:  1, norm0: 1.06e-02, normru: 1.10e-04, normre: 7.49e-06, normupdt: 2.28e-04, α:  0.533, eltime: 7.49 sec.
# iter:  2, norm0: 1.06e-02, normru: 3.35e-08, normre: 8.48e-08, eltime: 6.28 sec.
# step   2/10, LF=0.180, done in  3 iter, after 29.49 sec.
#
# predictor step done in 8.24 sec., with normupdt: 8.64e-01, starting corrector loop
# iter:  0, norm0: 2.03e-02, normru: 3.49e-02, normre: 1.05e-03, normupdt: 7.93e-03, α:  0.071, eltime: 7.48 sec.
# iter:  1, norm0: 2.02e-02, normru: 4.12e-05, normre: 4.83e-06, normupdt: 1.58e-04, α:  0.542, eltime: 9.17 sec.
# iter:  2, norm0: 2.02e-02, normru: 7.95e-09, normre: 3.62e-08, eltime: 8.71 sec.
# step   3/10, LF=0.360, done in  3 iter, after 33.61 sec.
#
# predictor step done in 7.95 sec., with normupdt: 8.63e-01, starting corrector loop
# iter:  0, norm0: 2.91e-02, normru: 2.18e-02, normre: 8.28e-04, normupdt: 6.60e-03, α:  0.064, eltime: 7.57 sec.
# iter:  1, norm0: 2.90e-02, normru: 2.12e-05, normre: 3.21e-06, normupdt: 1.15e-04, α:  0.542, eltime: 7.44 sec.
# iter:  2, norm0: 2.90e-02, normru: 2.77e-09, normre: 1.70e-08, eltime: 6.13 sec.
# step   4/10, LF=0.540, done in  3 iter, after 29.09 sec.
#
# predictor step done in 7.55 sec., with normupdt: 8.63e-01, starting corrector loop
# iter:  0, norm0: 3.72e-02, normru: 1.55e-02, normre: 6.61e-04, normupdt: 5.57e-03, α:  0.058, eltime: 7.53 sec.
# iter:  1, norm0: 3.72e-02, normru: 1.26e-05, normre: 2.17e-06, normupdt: 8.65e-05, α:  0.540, eltime: 7.51 sec.
# iter:  2, norm0: 3.72e-02, normru: 1.16e-09, normre: 8.58e-09, eltime: 6.16 sec.
# step   5/10, LF=0.720, done in  3 iter, after 28.75 sec.
#
# predictor step done in 7.49 sec., with normupdt: 8.63e-01, starting corrector loop
# iter:  0, norm0: 4.48e-02, normru: 1.18e-02, normre: 5.35e-04, normupdt: 4.75e-03, α:  0.053, eltime: 7.51 sec.
# iter:  1, norm0: 4.47e-02, normru: 8.10e-06, normre: 1.50e-06, eltime: 6.17 sec.
# step   6/10, LF=0.900, done in  2 iter, after 21.18 sec.
#
# predictor step done in 7.55 sec., with normupdt: 6.61e-05, starting corrector loop
# iter:  0, norm0: 4.47e-02, normru: 1.63e-05, normre: 3.00e-06, normupdt: 1.32e-04, α: -0.749, eltime: 7.43 sec.
# iter:  1, norm0: 4.47e-02, normru: 2.06e-09, normre: 1.83e-08, eltime: 6.21 sec.
# step   7/10, LF=0.900, done in  2 iter, after 21.19 sec.
#
# predictor step done in 7.50 sec., with normupdt: 1.60e-01, starting corrector loop
# iter:  0, norm0: 4.61e-02, normru: 2.00e-03, normre: 1.51e-05, normupdt: 1.45e-04, α:  0.052, eltime: 7.47 sec.
# iter:  1, norm0: 4.61e-02, normru: 4.04e-08, normre: 1.26e-09, eltime: 6.24 sec.
# step   8/10, LF=0.933, done in  2 iter, after 21.20 sec.
#
# predictor step done in 7.59 sec., with normupdt: 1.60e-01, starting corrector loop
# iter:  0, norm0: 4.74e-02, normru: 1.92e-03, normre: 1.45e-05, normupdt: 1.41e-04, α:  0.052, eltime: 7.46 sec.
# iter:  1, norm0: 4.74e-02, normru: 3.70e-08, normre: 1.15e-09, eltime: 6.11 sec.
# step   9/10, LF=0.967, done in  2 iter, after 21.16 sec.
#
# predictor step done in 7.52 sec., with normupdt: 1.60e-01, starting corrector loop
# iter:  0, norm0: 4.87e-02, normru: 1.84e-03, normre: 1.40e-05, normupdt: 1.37e-04, α:  0.051, eltime: 7.41 sec.
# iter:  1, norm0: 4.87e-02, normru: 3.45e-08, normre: 1.08e-09, eltime: 6.10 sec.
# step  10/10, LF=1.000, done in  2 iter, after 21.03 sec.
# completed in 4 minutes, 2 seconds

# %%
rf_tot_t = [sum(item[2][2,nid_bndt])   for item in allus_t]
Δu_tot_t = [mean(item[1][2,nid_bndt])  for item in allus_t]
;

# %%
JLD.save(sFileName*".jld",
            "nodes", nodes, "elems", elems,
            "points", points, "cells", cells, "mat", mat,
            "nid_bndl", nid_bndl, "nid_bndr", nid_bndr, 
            "nid_bndt", nid_bndt, "nid_bndb", nid_bndb, 
            "allus_t", allus_t, "allus_c", allus_c,          
            "LF_t", LF_t, "LF_c", LF_c,
            "rf_tot_t", rf_tot_t, "Δu_tot_t", Δu_tot_t,
            "rf_tot_c", rf_tot_c, "Δu_tot_c", Δu_tot_c,  
            "cntrs_s", cntrs_s, "cntrs_l", cntrs_l,
            "nid_shx", nid_shx, "nid_lhx", nid_lhx,
            "Δx", Δx, "Δy", Δy, "nNodes", nNodes, "nElems", nElems,
            "sMeshFile", sMeshFile, "sFileName", sFileName)
@printf("results written to %s\n", sFileName); flush(stdout)
;
# Out:
# results written to Pattern2D03FinerMesh02j

# %%
I1    = get_I1(elems, allus_t[end][1])

cfig  = figure()
ax1   = cfig.add_subplot(2,1,1)

plot_model(elems, nodes, alpha=0.05, 
  facecolor=:c, edgecolor=:c, cfig=cfig, ax=ax1)
plot_model(elems, nodes, u = allus_t[end][1], 
  edgecolor=:c, Φ = get_I1(elems, allus_t[end][1]), cfig=cfig, ax=ax1)
title("deformed model - tensile")

ax2   = cfig.add_subplot(2,1,2)
ax2.plot(Δu_tot_t, rf_tot_t)
xlabel("Δu_tot")
ylabel("rf_tot")
title("force-displacement, tensile branch")

cfig.tight_layout(pad=2.0, w_pad=2.0, h_pad=2.0)
;
# Out:
# Figure(PyObject <Figure size 640x480 with 3 Axes>)

# %%
PyPlot.figure()
PyPlot.plot(Δu_tot_c, rf_tot_c, Δu_tot_t, rf_tot_t)
PyPlot.xlabel("Δu_tot_")
PyPlot.ylabel("rf_tot_c")
PyPlot.title("force-displacement, total")
;
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
