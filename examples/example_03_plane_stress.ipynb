# %% [markdown]
# # Plane stress example

# %% [markdown]
# ### Preamble

# %% [markdown]
# - Include the necesary modules from Julia's standard repositories.
# - Here we run on 8 cores for parallel evaluation of the elements contribution to free energy

# %%
using Distributed
using Statistics, LinearAlgebra
using Printf, WriteVTK, AbaqusReader
using PyCall, PyPlot, JLD, ProgressMeter

# %%
# using AD4SM
include("adiff.jl")
include("materials.jl")
include("elements.jl")
;

# %% [markdown]
# this makes sure that the loop over the elements is split between 8 independent thread

# %%
@show Elements.setp(8)
;
# Out:
# Elements.setp(2) = 2

# %% [markdown]
# A few helper functions

# %%
# this function is the constraint equation for the internal holes
function cnst_func(u,ucntr,r0,cntr0,Rsq) 
    r    = r0+u
    cntr = cntr0+ucntr
    sum((r-cntr).^2)-Rsq
end
# this function find the centre of the constrained holes in the reference configuration
function find_centre(nodes; dTol = 1e-12, maxiter=21)

  c0    = mean(nodes)  
  bdone = false  
  iter  = 0

  while !bdone
    D2c0   = adiff.D2(c0)
    global deltas = [(D2c0[1]-p[1]).^2+(D2c0[2]-p[2]).^2 for p in nodes]
    r      = norm(deltas)
    grad   = adiff.grad(r)
    if (norm(grad)<dTol) || (iter>maxiter)
      bdone = true
    else
      c0  -= adiff.hess(r)\grad
    end
    iter +=1
  end
  Rsquares = adiff.val.(deltas) 
  return (c0, Rsquares)
end
    
# some plotting functions
patch = pyimport("matplotlib.patches")
coll  = pyimport("matplotlib.collections")  

function plot_model(elems, nodes; 
                    u = zeros(length(nodes[1]), length(nodes)),
                    Φ = [],
                    linewidth = 0.25,
                    facecolor = :c,
                    edgecolor = :b, 
                    alpha     = 1,
                    cmap      = :hsv,
                    clim      = [],
                    dTol      = 1e-6,
                    cfig      = figure(),
                    ax        = cfig.add_subplot(1,1,1))

  nodes     = [node + u[:,ii] for (ii,node) in enumerate(nodes)]
  patchcoll = coll.PatchCollection([patch.Polygon(nodes[elem.nodes]) 
                                    for elem ∈ elems], cmap=cmap)
  if !isempty(Φ)
    patchcoll.set_array(Φ)
    cfig.colorbar.(patchcoll, ax=ax)

    if isempty(clim)
      clim = patchcoll.get_clim()
      if abs(clim[2]-clim[1]) < dTol
        clim  = sum(clim)/2*[0.9, 1.1]
      end
    end
    patchcoll.set_clim(clim)
  else
    patchcoll.set_color(facecolor)
  end

  patchcoll.set_edgecolor(edgecolor)
  patchcoll.set_alpha(alpha)
  patchcoll.set_linewidth(linewidth)

  ax.set_aspect("equal")
  ax.add_collection(patchcoll)
  ax.autoscale()
  return (cfig, ax, patchcoll)
end
function get_I1(elems, u0)
      
    nElems = length(elems)
    F      = Elements.getinfo(elems,u0,info=:F)
    J      = [det(F)                       for F  in F]
    C      = [transpose(F)*F               for F  in F]
    L3     = [(C[1]C[4]-C[2]C[3])^-1       for C  in C]
    Ic     = [Materials.getInvariants(C[ii], L3[ii]) for ii in 1:nElems] 

    I1     = [item[1] for item in Ic]
end 
;

# %% [markdown]
# A few parameters controlling the simulation, file naming, output produced etc, are set

# %%
sMeshFile = "Pattern2D03FinerMesh02j.inp"
ϵn0       = 0.24
bfside    = true
mat       = Materials.NeoHooke(10)
bprogress = false
bwarmup   = true
blheqs    = false
bsheqs    = true
sFileName = splitext(sMeshFile)[1]
;

# %% [markdown]
# Load the mesh and store node sets

# %%
mymodel   = AbaqusReader.abaqus_read_mesh(sMeshFile)
@printf("\n\t loaded %s \n", sMeshFile)

(xmin, xmax) = extrema([item[2][1] for item ∈ mymodel["nodes"]])
(ymin, ymax) = extrema([item[2][2] for item ∈ mymodel["nodes"]])

nodes    = [mymodel["nodes"][ii]    for ii ∈ 1:length(mymodel["nodes"])]
el_nodes = [mymodel["elements"][ii] for ii ∈ 1:length(mymodel["elements"])]

elems = []
for item ∈ el_nodes
if length(item)==3
  push!(elems, Elements.Tria(item, nodes[item], mat=mat))
elseif length(item)==4
  push!(elems, Elements.Quad(item, nodes[item], mat=mat))
end
end    

points   = hcat(nodes...)
cells    = [if length(nodes)==3
            MeshCell(VTKCellTypes.VTK_TRIANGLE, nodes)
          else length(nodes)==4
            MeshCell(VTKCellTypes.VTK_QUAD, nodes)
          end  for nodes in el_nodes ]

@show nNodes, nElems  = length(nodes), length(el_nodes)
@show Δx, Δy          = (xmax-xmin), (ymax-ymin)

nid_bndl = mymodel["node_sets"]["ID_L"]
nid_bndr = mymodel["node_sets"]["ID_R"]
nid_bndt = mymodel["node_sets"]["ID_T"]
nid_bndb = mymodel["node_sets"]["ID_B"]

nid_sh01 = mymodel["node_sets"]["ID_SH01"]
nid_sh02 = mymodel["node_sets"]["ID_SH02"]
nid_sh03 = mymodel["node_sets"]["ID_SH03"]
nid_sh04 = mymodel["node_sets"]["ID_SH04"]
nid_sh05 = mymodel["node_sets"]["ID_SH05"]
nid_sh06 = mymodel["node_sets"]["ID_SH06"]
nid_sh07 = mymodel["node_sets"]["ID_SH07"]
nid_sh08 = mymodel["node_sets"]["ID_SH08"]
nid_sh09 = mymodel["node_sets"]["ID_SH09"]

nid_shx  = [nid_sh01, nid_sh02, nid_sh03,
          nid_sh04, nid_sh05, nid_sh06,
          nid_sh07, nid_sh08, nid_sh09]
nSHs     = length(nid_shx)

nid_lh01 = mymodel["node_sets"]["ID_LH01"]
nid_lh02 = mymodel["node_sets"]["ID_LH02"]
nid_lh03 = mymodel["node_sets"]["ID_LH03"]
nid_lh04 = mymodel["node_sets"]["ID_LH04"]
nid_lh05 = mymodel["node_sets"]["ID_LH05"]
nid_lh06 = mymodel["node_sets"]["ID_LH06"]
nid_lh07 = mymodel["node_sets"]["ID_LH07"]
nid_lh08 = mymodel["node_sets"]["ID_LH08"]
nid_lh09 = mymodel["node_sets"]["ID_LH09"]
nid_lh10 = mymodel["node_sets"]["ID_LH10"]
nid_lh11 = mymodel["node_sets"]["ID_LH11"]
nid_lh12 = mymodel["node_sets"]["ID_LH12"]
nid_lh13 = mymodel["node_sets"]["ID_LH13"]
nid_lh14 = mymodel["node_sets"]["ID_LH14"]
nid_lh15 = mymodel["node_sets"]["ID_LH15"]
nid_lh16 = mymodel["node_sets"]["ID_LH16"]

nid_lhx  = [nid_lh01, nid_lh02, nid_lh03,
          nid_lh04, nid_lh05, nid_lh06,
          nid_lh07, nid_lh08, nid_lh09, nid_lh10,
          nid_lh11, nid_lh12, nid_lh13,
          nid_lh14, nid_lh15, nid_lh16]
nLHs     = length(nid_lhx)

cntrs_s = [find_centre(nodes[idx]) for idx in nid_shx]
cntrs_l = [find_centre(nodes[idx]) for idx in nid_lhx]
nodes = vcat(nodes,getindex.(cntrs_s,1),getindex.(cntrs_l,1))
;
# Out:
# ┌ Info: 11678 nodes found
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:109
# ┌ Info: Parsing elements. Type: CPS4. Topology: Quad4
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:153
# ┌ Info: Creating nset ID_L
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_L
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_R
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_R
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_T
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_T
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_B
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_B
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ALL
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ALL
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_SH01
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_SH01
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_SH02
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_SH02
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_SH03
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_SH03
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_SH04
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_SH04
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_SH05
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_SH05
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_SH06
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_SH06
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_SH07
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_SH07
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_SH08
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_SH08
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_SH09
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_SH09
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH01
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH01
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH02
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH02
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH03
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH03
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH04
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH04
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH05
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH05
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH06
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH06
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH07
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH07
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH08
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH08
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH09
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH09
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH10
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH10
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# 	 loaded Pattern2D03FinerMesh02j.inp
# (nNodes, nElems) = (length(nodes), length(el_nodes)) =
# ┌ Info: Creating nset ID_LH11
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH11
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH12
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH12
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH13
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH13
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH14
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH14
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH15
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH15
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating nset ID_LH16
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# ┌ Info: Creating elset ID_LH16
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/SDhGN/src/parse_mesh.jl:187
# (11678, 10832)
# (Δx, Δy) = (xmax - xmin, ymax - ymin) = (20.0, 20.0)

# %%
plot_model(elems, nodes, facecolor=:c, edgecolor=:c)
PyPlot.title("undeformed model")
;
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Write constraint equations for the holes:
#  - if bsheqs is true eqautions are added for the smaller holes
#  - if blheqs is true equations are added for the larger holes

# %%
idxs  = LinearIndices(((2, nNodes+nSHs+nLHs)))
eqns  = Array{Elements.ConstEq}(undef, 0)
if bsheqs
    eqns  = vcat(eqns,
                 [ [ begin
                      r0      = nodes[nid]
                      cntr0   = nodes[nNodes+ii]
                      Rsq     = cntrs_s[ii][2][jj]
                      id_dofs = vcat(idxs[:,nid][:],idxs[:,nNodes+ii][:])
                      Elements.ConstEq(x->cnst_func(x[1:2],x[3:4],r0,cntr0,Rsq), 
                                       id_dofs,adiff.D2) 
                    end  for (jj,nid) in enumerate(nid_ii)] 
                  for (ii,nid_ii) in enumerate(nid_shx)]...)
end
if blheqs
    eqns = vcat(eqns,
                [ [ begin
                     r0      = nodes[nid]
                     cntr0   = nodes[nNodes+nSHs+ii]
                     Rsq     = cntrs_l[ii][2][jj]
                     id_dofs = vcat(idxs[:,nid][:],idxs[:,nNodes+nSHs+ii][:])
                     Elements.ConstEq(x->cnst_func(x[1:2],x[3:4],r0,cntr0,Rsq), 
                                      id_dofs,adiff.D2) 
                   end  for (jj,nid) in enumerate(nid_ii)] 
                 for (ii,nid_ii) in enumerate(nid_lhx)]... )
end
;

# %% [markdown]
# prepare a few arrays needed to start the solution
# - u is the displacement vector, it contains the boundary conditions,
# - ifree is an array of boolean with the same dimension of u, if ifree is true that DoFs is free, otherwise it is constrained, and the value of the constraint is stored in u

# %% [markdown]
# ### Do the compressive branch

# %% [markdown]
# - initialize the displacement vector and the boundary conditions: u is the array with the DoFs, the NaN entries in u are free DoFs, the !NaN entries are the boundary conditions

# %%
u                  = fill(NaN, 2, nNodes+nSHs+nLHs)
u[:,nid_bndb]     .= 0
u[1,nid_bndt]     .= 0 
u[2,nid_bndt]     .= -ϵn0*Δy

if !bsheqs u[:,nNodes+1:nNodes+nSHs] .= NaN; end
if !blheqs u[:,nNodes+nSHs+1:end]    .= NaN; end

if !bfside
    u[1,nid_bndl] .= 0 
    u[1,nid_bndr] .= 0 
end

ifree     = isnan.(u)
icnst     = .!ifree
;

# %% [markdown]
# - this is a preliminary step, for making sure all constranints are initially satisfied and avoid non-convergence on the first step, the result is used as initial condition for the simulation

# %%
u0         = 1e-4Δx*randn(2, nNodes+nSHs+nLHs)
u0[icnst] .= 0
unew       = copy(u0)
@time Elements.solvestep!(elems, u0, unew, ifree, eqns=eqns, λ = zeros(length(eqns)),
                          bprogress=false, becho=true)
u[ifree] .= unew[ifree]
;
# Out:
# predictor step done in 33.85 sec., starting corrector loop
# iter:  0, norm0: 9.17e-03, normru: 4.57e-01, normre: 3.58e-02, normupdt: 3.01e-02, α: -0.909, eltime: 27.08 sec.
# iter:  1, norm0: 4.96e-04, normru: 4.16e-01, normre: 3.33e-04, normupdt: 4.03e-02, α: -0.817, eltime: 25.08 sec.
# iter:  2, norm0: 2.52e-06, normru: 3.00e-06, normre: 1.03e-05, eltime: 23.49 sec.
# 115.739870 seconds (39.66 M allocations: 152.852 GiB, 10.54% gc time)

# %% [markdown]
# ### Do the compressive branch

# %%
N       = 15
LF_c    = vcat(range(0.0, 0.9, length=2N÷3),
               range(0.9, 1.0, length=N÷3+1))

allus_c = Elements.solve(elems, u, LF=LF_c, ifree=ifree, eqns=eqns,
                          bprogress=false, becho=true, bechoi=true)
;
# Out:
# predictor step done in 14.29 sec., starting corrector loop
# iter:  0, norm0: 0.00e+00, normru: 0.00e+00, normre: 0.00e+00, eltime: 11.85 sec.
# step   1/10, LF=0.000, done in  1 iter, after 26.13 sec.
#
# predictor step done in 13.28 sec., starting corrector loop
# iter:  0, norm0: 1.17e-02, normru: 7.45e-02, normre: 1.36e-03, normupdt: 9.74e-01, α:  0.093, eltime: 13.20 sec.
# iter:  1, norm0: 1.17e-02, normru: 1.05e-04, normre: 6.90e-06, normupdt: 8.81e-04, α:  0.536, eltime: 13.18 sec.
# iter:  2, norm0: 1.17e-02, normru: 5.44e-08, normre: 1.03e-07, eltime: 11.71 sec.
# step   2/10, LF=0.180, done in  3 iter, after 51.38 sec.
#
# predictor step done in 13.31 sec., starting corrector loop
# iter:  0, norm0: 2.48e-02, normru: 4.08e-02, normre: 1.78e-03, normupdt: 1.18e+00, α:  0.107, eltime: 13.27 sec.
# iter:  1, norm0: 2.49e-02, normru: 7.28e-05, normre: 1.07e-05, normupdt: 1.52e-03, α:  0.506, eltime: 14.47 sec.
# iter:  2, norm0: 2.49e-02, normru: 6.81e-08, normre: 2.73e-07, eltime: 12.33 sec.
# step   3/10, LF=0.360, done in  3 iter, after 53.37 sec.
#
# predictor step done in 13.34 sec., starting corrector loop
# iter:  0, norm0: 3.97e-02, normru: 3.04e-02, normre: 2.39e-03, normupdt: 1.45e+00, α:  0.125, eltime: 13.37 sec.
# iter:  1, norm0: 3.97e-02, normru: 7.39e-05, normre: 1.75e-05, normupdt: 2.98e-03, α:  0.437, eltime: 13.44 sec.
# iter:  2, norm0: 3.97e-02, normru: 1.51e-07, normre: 8.23e-07, eltime: 11.89 sec.
# step   4/10, LF=0.540, done in  3 iter, after 52.05 sec.
#
# predictor step done in 13.37 sec., starting corrector loop
# iter:  0, norm0: 5.67e-02, normru: 2.58e-02, normre: 3.40e-03, normupdt: 1.82e+00, α:  0.147, eltime: 13.49 sec.
# iter:  1, norm0: 5.65e-02, normru: 1.05e-04, normre: 3.15e-05, normupdt: 7.00e-03, α:  0.318, eltime: 13.36 sec.
# iter:  2, norm0: 5.65e-02, normru: 8.31e-07, normre: 3.22e-06, eltime: 11.95 sec.
# step   5/10, LF=0.720, done in  3 iter, after 52.18 sec.
#
# predictor step done in 13.20 sec., starting corrector loop
# iter:  0, norm0: 7.59e-02, normru: 2.39e-02, normre: 5.17e-03, normupdt: 2.40e+00, α:  0.176, eltime: 13.23 sec.
# iter:  1, norm0: 7.53e-02, normru: 2.57e-04, normre: 7.65e-05, normupdt: 2.06e-02, α:  0.124, eltime: 13.30 sec.
# iter:  2, norm0: 7.53e-02, normru: 1.73e-05, normre: 2.71e-05, normupdt: 1.80e-04, α:  0.852, eltime: 13.56 sec.
# iter:  3, norm0: 7.53e-02, normru: 2.24e-08, normre: 1.02e-09, eltime: 11.93 sec.
# step   6/10, LF=0.900, done in  4 iter, after 65.22 sec.
#
# predictor step done in 13.14 sec., starting corrector loop
# iter:  0, norm0: 7.53e-02, normru: 4.52e-08, normre: 2.04e-09, eltime: 11.70 sec.
# step   7/10, LF=0.900, done in  1 iter, after 24.83 sec.
#
# predictor step done in 13.26 sec., starting corrector loop
# iter:  0, norm0: 7.89e-02, normru: 4.78e-03, normre: 3.48e-04, normupdt: 5.70e-01, α:  0.226, eltime: 13.14 sec.
# iter:  1, norm0: 7.89e-02, normru: 2.92e-05, normre: 1.58e-05, normupdt: 2.46e-02, α:  0.399, eltime: 13.15 sec.
# iter:  2, norm0: 7.89e-02, normru: 1.34e-05, normre: 1.10e-05, normupdt: 1.18e-03, α:  0.999, eltime: 13.14 sec.
# iter:  3, norm0: 7.89e-02, normru: 2.94e-08, normre: 1.69e-08, eltime: 11.75 sec.
# step   8/10, LF=0.933, done in  4 iter, after 64.43 sec.
#
# predictor step done in 13.45 sec., starting corrector loop
# iter:  0, norm0: 8.26e-02, normru: 6.01e-03, normre: 2.23e-03, normupdt: 7.87e-01, α:  0.860, eltime: 13.74 sec.
# iter:  1, norm0: 8.20e-02, normru: 2.75e-03, normre: 2.16e-03, normupdt: 4.64e-01, α:  0.972, eltime: 13.16 sec.
# iter:  2, norm0: 8.05e-02, normru: 3.56e-03, normre: 3.78e-03, normupdt: 4.00e-01, α:  0.996, eltime: 13.09 sec.
# iter:  3, norm0: 7.89e-02, normru: 3.02e-03, normre: 2.24e-03, normupdt: 3.12e-01, α:  0.998, eltime: 13.17 sec.
# iter:  4, norm0: 7.74e-02, normru: 2.48e-03, normre: 1.42e-03, normupdt: 1.95e-01, α:  0.991, eltime: 14.25 sec.
# iter:  5, norm0: 7.64e-02, normru: 2.14e-03, normre: 6.33e-04, normupdt: 9.11e-02, α:  0.994, eltime: 13.17 sec.
# iter:  6, norm0: 7.60e-02, normru: 5.72e-04, normre: 1.37e-04, normupdt: 4.88e-02, α:  0.984, eltime: 13.74 sec.
# iter:  7, norm0: 7.57e-02, normru: 4.66e-04, normre: 3.47e-05, normupdt: 5.29e-03, α:  0.903, eltime: 13.51 sec.
# iter:  8, norm0: 7.57e-02, normru: 1.44e-05, normre: 3.29e-07, normupdt: 4.01e-04, α:  0.882, eltime: 13.53 sec.
# iter:  9, norm0: 7.57e-02, normru: 1.18e-07, normre: 1.17e-09, eltime: 11.73 sec.
# step   9/10, LF=0.967, done in 10 iter, after 146.54 sec.
#
# predictor step done in 13.32 sec., starting corrector loop
# iter:  0, norm0: 7.51e-02, normru: 2.35e-02, normre: 1.40e-02, normupdt: 1.28e+00, α: -0.615, eltime: 14.57 sec.
# iter:  1, norm0: 7.41e-02, normru: 8.37e-02, normre: 6.15e-04, normupdt: 1.68e-01, α:  0.373, eltime: 14.05 sec.
# iter:  2, norm0: 7.49e-02, normru: 3.38e-02, normre: 4.94e-04, normupdt: 7.84e-02, α:  0.336, eltime: 14.90 sec.
# iter:  3, norm0: 7.53e-02, normru: 2.14e-02, normre: 8.29e-05, normupdt: 1.03e-01, α: -0.748, eltime: 14.47 sec.
# iter:  4, norm0: 7.48e-02, normru: 1.74e-01, normre: 2.19e-04, normupdt: 9.83e-02, α: -0.934, eltime: 14.59 sec.
# iter:  5, norm0: 7.52e-02, normru: 6.93e-02, normre: 7.02e-05, normupdt: 5.48e-02, α:  0.178, eltime: 13.42 sec.
# iter:  6, norm0: 7.52e-02, normru: 4.41e-02, normre: 6.61e-05, normupdt: 3.65e-02, α: -0.099, eltime: 13.39 sec.
# iter:  7, norm0: 7.52e-02, normru: 1.54e-02, normre: 1.08e-05, normupdt: 3.80e-02, α: -0.472, eltime: 13.87 sec.
# iter:  8, norm0: 7.53e-02, normru: 5.56e-03, normre: 1.56e-05, normupdt: 6.97e-02, α: -0.213, eltime: 14.06 sec.
# iter:  9, norm0: 7.51e-02, normru: 8.46e-03, normre: 5.09e-05, normupdt: 3.55e-02, α: -0.285, eltime: 13.20 sec.
# iter: 10, norm0: 7.50e-02, normru: 6.27e-03, normre: 5.85e-06, normupdt: 5.24e-02, α:  0.527, eltime: 14.87 sec.
# iter: 11, norm0: 7.51e-02, normru: 1.16e-03, normre: 1.88e-05, eltime: 12.53 sec.
#
# !! failed at LF: 1.000, with normr/dTol: 1.160e+02
# completed in 11 minutes, 57 seconds

# %%
rf_tot_c = [sum(item[2][2,nid_bndt])   for item in allus_c]
Δu_tot_c = [mean(item[1][2,nid_bndt])  for item in allus_c]
;

# %% [markdown]
# - plot the results

# %%
I1 = get_I1(elems, allus_c[end][1])

cfig = figure()
ax1   = cfig.add_subplot(2,1,1)

plot_model(elems, nodes, alpha=0.05, 
  facecolor=:c, edgecolor=:c, cfig=cfig, ax=ax1)
plot_model(elems, nodes, u = allus_c[end][1], 
  edgecolor=:c, Φ = get_I1(elems, allus_c[end][1]), cfig=cfig, ax=ax1)
title("deformed model - compression")

ax2   = cfig.add_subplot(2,1,2)
ax2.plot(Δu_tot_c, rf_tot_c)
xlabel("Δu_tot_")
ylabel("rf_tot_c")
title("force-displacement, compressive branch")

cfig.tight_layout(pad=2.0, w_pad=2.0, h_pad=2.0)
;
# Out:
# Figure(PyObject <Figure size 640x480 with 3 Axes>)

# %% [markdown]
# ### Do the tensile branch

# %%
u                  = fill(NaN, 2, nNodes+nSHs+nLHs)
u[:,nid_bndb]     .= 0
u[1,nid_bndt]     .= 0 
u[2,nid_bndt]     .= ϵn0*Δy

if !bsheqs u[:,nNodes+1:nNodes+nSHs] .= NaN; end
if !blheqs u[:,nNodes+nSHs+1:end]    .= NaN; end

if !bfside
    u[1,nid_bndl]     .= 0 
    u[1,nid_bndr]     .= 0 
end

ifree     = isnan.(u)
icnst     = .!ifree
;

# %%
u0         = 1e-4Δx*randn(2, nNodes+nSHs+nLHs)
u0[icnst] .= 0
unew       = copy(u0)
@time Elements.solvestep!(elems, u0, unew, ifree, eqns=eqns, λ = zeros(length(eqns)),
                          bprogress=false, becho=true)
u[ifree] .= unew[ifree]
;
# Out:
# predictor step done in 14.33 sec., starting corrector loop
# iter:  0, norm0: 8.77e-03, normru: 4.79e-01, normre: 2.76e-02, normupdt: 5.01e-02, α: -0.906, eltime: 14.66 sec.
# iter:  1, norm0: 4.51e-04, normru: 4.60e-01, normre: 3.32e-04, normupdt: 6.76e-02, α: -0.816, eltime: 14.17 sec.
# iter:  2, norm0: 2.75e-06, normru: 2.86e-06, normre: 5.14e-06, eltime: 12.28 sec.
#  55.437200 seconds (16.10 M allocations: 86.997 GiB, 15.01% gc time)

# %%
N       = 10
LF_t    = vcat(range(0.0, 0.9, length=2N÷3),
               range(0.9, 1.0, length=N÷3+1))
println("\n\t starting the tensile branch \n"); flush(stdout)
allus_t = Elements.solve(elems, u, LF=LF_t, ifree=ifree, eqns=eqns,
                          bprogress=false, becho=true, bechoi=true)
;
# Out:
# 	 starting the tensile branch
#
#
# predictor step done in 14.24 sec., starting corrector loop
# iter:  0, norm0: 0.00e+00, normru: 0.00e+00, normre: 0.00e+00, eltime: 12.68 sec.
# step   1/10, LF=0.000, done in  1 iter, after 26.92 sec.
#
# predictor step done in 13.72 sec., starting corrector loop
# iter:  0, norm0: 1.06e-02, normru: 7.49e-02, normre: 1.36e-03, normupdt: 8.93e-01, α:  0.080, eltime: 13.61 sec.
# iter:  1, norm0: 1.06e-02, normru: 1.10e-04, normre: 7.49e-06, normupdt: 6.80e-04, α:  0.533, eltime: 13.82 sec.
# iter:  2, norm0: 1.06e-02, normru: 3.35e-08, normre: 8.48e-08, eltime: 12.82 sec.
# step   2/10, LF=0.180, done in  3 iter, after 53.97 sec.
#
# predictor step done in 14.06 sec., starting corrector loop
# iter:  0, norm0: 2.03e-02, normru: 3.49e-02, normre: 1.05e-03, normupdt: 7.63e-01, α:  0.071, eltime: 13.79 sec.
# iter:  1, norm0: 2.02e-02, normru: 4.12e-05, normre: 4.83e-06, normupdt: 4.58e-04, α:  0.542, eltime: 18.20 sec.
# iter:  2, norm0: 2.02e-02, normru: 7.95e-09, normre: 3.62e-08, eltime: 12.90 sec.
# step   3/10, LF=0.360, done in  3 iter, after 58.95 sec.
#
# predictor step done in 16.76 sec., starting corrector loop
# iter:  0, norm0: 2.91e-02, normru: 2.18e-02, normre: 8.28e-04, normupdt: 6.65e-01, α:  0.064, eltime: 15.20 sec.
# iter:  1, norm0: 2.90e-02, normru: 2.12e-05, normre: 3.21e-06, normupdt: 3.18e-04, α:  0.542, eltime: 15.73 sec.
# iter:  2, norm0: 2.90e-02, normru: 2.77e-09, normre: 1.70e-08, eltime: 12.08 sec.
# step   4/10, LF=0.540, done in  3 iter, after 59.77 sec.
#
# predictor step done in 14.52 sec., starting corrector loop
# iter:  0, norm0: 3.72e-02, normru: 1.55e-02, normre: 6.61e-04, normupdt: 5.90e-01, α:  0.058, eltime: 15.03 sec.
# iter:  1, norm0: 3.72e-02, normru: 1.26e-05, normre: 2.17e-06, normupdt: 2.27e-04, α:  0.540, eltime: 14.08 sec.
# iter:  2, norm0: 3.72e-02, normru: 1.16e-09, normre: 8.58e-09, eltime: 12.06 sec.
# step   5/10, LF=0.720, done in  3 iter, after 55.69 sec.
#
# predictor step done in 13.30 sec., starting corrector loop
# iter:  0, norm0: 4.48e-02, normru: 1.18e-02, normre: 5.35e-04, normupdt: 5.32e-01, α:  0.053, eltime: 13.68 sec.
# iter:  1, norm0: 4.47e-02, normru: 8.10e-06, normre: 1.50e-06, eltime: 12.10 sec.
# step   6/10, LF=0.900, done in  2 iter, after 39.08 sec.
#
# predictor step done in 13.43 sec., starting corrector loop
# iter:  0, norm0: 4.47e-02, normru: 1.63e-05, normre: 3.00e-06, normupdt: 1.32e-04, α: -0.749, eltime: 13.57 sec.
# iter:  1, norm0: 4.47e-02, normru: 2.06e-09, normre: 1.83e-08, eltime: 12.05 sec.
# step   7/10, LF=0.900, done in  2 iter, after 39.06 sec.
#
# predictor step done in 13.48 sec., starting corrector loop
# iter:  0, norm0: 4.61e-02, normru: 2.00e-03, normre: 1.51e-05, normupdt: 9.17e-02, α:  0.052, eltime: 13.87 sec.
# iter:  1, norm0: 4.61e-02, normru: 4.04e-08, normre: 1.26e-09, eltime: 12.41 sec.
# step   8/10, LF=0.933, done in  2 iter, after 39.76 sec.
#
# predictor step done in 15.82 sec., starting corrector loop
# iter:  0, norm0: 4.74e-02, normru: 1.92e-03, normre: 1.45e-05, normupdt: 9.03e-02, α:  0.052, eltime: 15.06 sec.
# iter:  1, norm0: 4.74e-02, normru: 3.70e-08, normre: 1.15e-09, eltime: 12.23 sec.
# step   9/10, LF=0.967, done in  2 iter, after 43.10 sec.
#
# predictor step done in 13.43 sec., starting corrector loop
# iter:  0, norm0: 4.87e-02, normru: 1.84e-03, normre: 1.40e-05, normupdt: 8.89e-02, α:  0.051, eltime: 13.31 sec.
# iter:  1, norm0: 4.87e-02, normru: 3.45e-08, normre: 1.08e-09, eltime: 12.88 sec.
# step  10/10, LF=1.000, done in  2 iter, after 39.63 sec.
# completed in 7 minutes, 35 seconds

# %%
rf_tot_t = [sum(item[2][2,nid_bndt])   for item in allus_t]
Δu_tot_t = [mean(item[1][2,nid_bndt])  for item in allus_t]
;

# %%
JLD.save(sFileName*".jld",
            "nodes", nodes, "elems", elems,
            "points", points, "cells", cells, "mat", mat,
            "nid_bndl", nid_bndl, "nid_bndr", nid_bndr, 
            "nid_bndt", nid_bndt, "nid_bndb", nid_bndb, 
            "allus_t", allus_t, "allus_c", allus_c,          
            "LF_t", LF_t, "LF_c", LF_c,
            "rf_tot_t", rf_tot_t, "Δu_tot_t", Δu_tot_t,
            "rf_tot_c", rf_tot_c, "Δu_tot_c", Δu_tot_c,  
            "cntrs_s", cntrs_s, "cntrs_l", cntrs_l,
            "nid_shx", nid_shx, "nid_lhx", nid_lhx,
            "Δx", Δx, "Δy", Δy, "nNodes", nNodes, "nElems", nElems,
            "sMeshFile", sMeshFile, "sFileName", sFileName)
@printf("results written to %s\n", sFileName); flush(stdout)
;
# Out:
# results written to Pattern2D03FinerMesh02j

# %%
I1    = get_I1(elems, allus_t[end][1])

cfig  = figure()
ax1   = cfig.add_subplot(2,1,1)

plot_model(elems, nodes, alpha=0.05, 
  facecolor=:c, edgecolor=:c, cfig=cfig, ax=ax1)
plot_model(elems, nodes, u = allus_t[end][1], 
  edgecolor=:c, Φ = get_I1(elems, allus_t[end][1]), cfig=cfig, ax=ax1)
title("deformed model - tensile")

ax2   = cfig.add_subplot(2,1,2)
ax2.plot(Δu_tot_t, rf_tot_t)
xlabel("Δu_tot")
ylabel("rf_tot")
title("force-displacement, tensile branch")

cfig.tight_layout(pad=2.0, w_pad=2.0, h_pad=2.0)
;
# Out:
# Figure(PyObject <Figure size 640x480 with 3 Axes>)

# %%
PyPlot.figure()
PyPlot.plot(Δu_tot_c, rf_tot_c, Δu_tot_t, rf_tot_t)
PyPlot.xlabel("Δu_tot_")
PyPlot.ylabel("rf_tot_c")
PyPlot.title("force-displacement, tensile branch")
;
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
