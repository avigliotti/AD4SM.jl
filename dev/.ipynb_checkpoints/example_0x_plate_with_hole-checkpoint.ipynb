# %% [markdown]
# # Plane stress example

# %% [markdown]
# using a julia 1.2.0 kernel

# %% [markdown]
# ### Preamble

# %% [markdown]
# - Include the necesary modules from Julia's standard repositories.
# - Here we run on 4 cores for parallel evaluation of the elements contribution to free energy

# %%
using Distributed
using Statistics, LinearAlgebra
using Printf, WriteVTK, AbaqusReader
using PyCall, PyPlot, JLD, ProgressMeter

# %% [raw]
# using AD4SM

# %% [raw]
# include("/home/andrea/Documents/github/AD4SM.jl/src/AD4SM.jl")

# %%
let sPath = "/home/andrea/Documents/github/AD4SM.jl/src/"
  include(sPath*"adiff.jl")
  include(sPath*"materials.jl")
  include(sPath*"elements.jl")
end
# Out:
# Main.Elements

# %% [markdown]
# this makes sure that the loop over the elements is split between 4 independent thread

# %% [raw]
# @show Elements.setp(4)
# ;

# %% [markdown]
# A few helper functions

# %%
# this function is the constraint equation for the internal holes
function cnst_func(u,ucntr,r0,cntr0,Rsq) 
    r    = r0+u
    cntr = cntr0+ucntr
    sum((r-cntr).^2)-Rsq
end
# this function find the centre of the constrained holes in the reference configuration
function find_centre(nodes; dTol = 1e-12, maxiter=21)

  c0    = mean(nodes)  
  bdone = false  
  iter  = 0

  while !bdone
    D2c0   = adiff.D2(c0)
    global deltas = [(D2c0[1]-p[1]).^2+(D2c0[2]-p[2]).^2 for p in nodes]
    r      = norm(deltas)
    grad   = adiff.grad(r)
    if (norm(grad)<dTol) || (iter>maxiter)
      bdone = true
    else
      c0  -= adiff.hess(r)\grad
    end
    iter +=1
  end
  Rsquares = adiff.val.(deltas) 
  return (c0, Rsquares)
end
    
# some plotting functions
patch = pyimport("matplotlib.patches")
coll  = pyimport("matplotlib.collections")  

function plot_model(elems, nodes; 
                    u = zeros(length(nodes[1]), length(nodes)),
                    Φ = [],
                    linewidth = 0.25,
                    facecolor = :c,
                    edgecolor = :b, 
                    alpha     = 1,
                    cmap      = :hsv,
                    clim      = [],
                    dTol      = 1e-6,
                    cfig      = figure(),
                    ax        = cfig.add_subplot(1,1,1))

  nodes     = [node + u[:,ii] for (ii,node) in enumerate(nodes)]
  patchcoll = coll.PatchCollection([patch.Polygon(nodes[elem.nodes]) 
                                    for elem ∈ elems], cmap=cmap)
  if !isempty(Φ)
    patchcoll.set_array(Φ)
    cfig.colorbar.(patchcoll, ax=ax)

    if isempty(clim)
      clim = patchcoll.get_clim()
      if abs(clim[2]-clim[1]) < dTol
        clim  = sum(clim)/2*[0.9, 1.1]
      end
    end
    patchcoll.set_clim(clim)
  else
    patchcoll.set_color(facecolor)
  end

  patchcoll.set_edgecolor(edgecolor)
  patchcoll.set_alpha(alpha)
  patchcoll.set_linewidth(linewidth)

  ax.set_aspect("equal")
  ax.add_collection(patchcoll)
  ax.autoscale()
  return (cfig, ax, patchcoll)
end
function get_I1(elems, u0)
      
    nElems = length(elems)
    F      = Elements.getinfo(elems,u0,info=:F)
    J      = [det(F)                       for F  in F]
    C      = [transpose(F)*F               for F  in F]
    L3     = [(C[1]C[4]-C[2]C[3])^-1       for C  in C]
    Ic     = [Materials.getInvariants(C[ii], L3[ii]) for ii in 1:nElems] 

    I1     = [item[1] for item in Ic]
end 
;

# %% [markdown]
# A few parameters controlling the simulation, file naming, output produced etc, are set

# %%
# sMeshFile = "Pattern2D03FinerMesh02j.inp"
# sMeshFile = "phole.inp"
sMeshFile = "phole_h0125.inp"
ϵn0       = 0.24
bfside    = true
mat       = Materials.Ogden(18,1)
# mat       = Materials.NeoHooke(10)
bprogress = false
bwarmup   = true
blheqs    = false
bsheqs    = true
sFileName = splitext(sMeshFile)[1]
;

# %% [markdown]
# Load the mesh and store node sets

# %%
mymodel   = AbaqusReader.abaqus_read_mesh(sMeshFile)
@printf("\n\t loaded %s \n", sMeshFile)
# Out:
# 	 loaded phole_h0125.inp
# ┌ Warning: Unknown section: 'HEADING'
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/C1mY0/src/parse_mesh.jl:270
# ┌ Info: 2065 nodes found
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/C1mY0/src/parse_mesh.jl:109
# ┌ Info: Parsing elements. Type: CPS4. Topology: Quad4
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/C1mY0/src/parse_mesh.jl:153
# ┌ Info: Adding elset: Surface3
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/C1mY0/src/parse_mesh.jl:88
# ┌ Info: Creating nset bottom_bnd
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/C1mY0/src/parse_mesh.jl:187
# ┌ Info: Creating nset right_bnd
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/C1mY0/src/parse_mesh.jl:187
# ┌ Info: Creating nset top_bnd
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/C1mY0/src/parse_mesh.jl:187
# ┌ Info: Creating nset left_bnd
# └ @ AbaqusReader /home/andrea/.julia/packages/AbaqusReader/C1mY0/src/parse_mesh.jl:187

# %%
(xmin, xmax) = extrema([item[2][1] for item ∈ mymodel["nodes"]])
(ymin, ymax) = extrema([item[2][2] for item ∈ mymodel["nodes"]])

nodes    = [mymodel["nodes"][ii][1:2]    for ii ∈ 1:length(mymodel["nodes"])]
el_nodes = [elem for elem ∈ values(mymodel["elements"])]

elems = []
for item ∈ el_nodes
if length(item)==3
  push!(elems, Elements.Tria(item, nodes[item], mat=mat))
elseif length(item)==4
  push!(elems, Elements.Quad(item, nodes[item], mat=mat))
end
end    

points   = hcat(nodes...)
cells    = [if length(nodes)==3
            MeshCell(VTKCellTypes.VTK_TRIANGLE, nodes)
          else length(nodes)==4
            MeshCell(VTKCellTypes.VTK_QUAD, nodes)
          end  for nodes in el_nodes ]
;

nid_bndl = mymodel["node_sets"]["left_bnd"]
nid_bndr = mymodel["node_sets"]["right_bnd"]
nid_bndt = mymodel["node_sets"]["top_bnd"]
nid_bndb = mymodel["node_sets"]["bottom_bnd"]
;

# %%
plot_model(elems, nodes, facecolor=:c, edgecolor=:b)

PyPlot.plot([node[1] for node in nodes[nid_bndt]], 
  [node[2] for node in nodes[nid_bndt]], marker=:o, linestyle=:none, markerfacecolor=:none)

PyPlot.plot([node[1] for node in nodes[nid_bndb]], 
  [node[2] for node in nodes[nid_bndb]], marker=:o, linestyle=:none, markerfacecolor=:none)

PyPlot.title("undeformed model")
;
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Write constraint equations for the holes:
#  - if bsheqs is true equations are added for the smaller holes
#  - if blheqs is true equations are added for the larger holes

# %% [raw]
# function getϕ(F::Array{N,2}, mat::Materials.Ogden) where {N<:Number}
#
#   μ, α, K = mat.μ, mat.α, mat.K
#
#   if length(F) == 9
#     C = transpose(F)F
#   else
#     F33 = isnan(K) ? 1/(F[1]F[4]-F[2]F[3]) : one(F[1])
#     F3D = fill(zero(F[1]), (3,3))
#     F3D[1:2,1:2] = F
#     F3D[9] = F33
#     C   = transpose(F3D)*F3D
#   end
#
#   λ = svdvals(C)
#   ϕ = μ/α * (sum(λ.^α) - 3)
#   if !isnan(K)
#     ϕ += K*log(getI3(C))
#   end
#
#   ϕ
# end

# %% [raw]
# function getϕ(elem::T where T<:Elements.CElems, u::Array{<:Number,2})
#   M = length(elem.wgt)
#   if isa(u[1], adiff.D2)
#     ϕ = sum([begin
#                F = Elements.getF(elem,u,ii)
#                ϕ = getϕ(adiff.D2(getfield.(F,:v)),elem.mat)
#                elem.wgt[ii]Elements.cross(ϕ,F)
#              end  for ii in 1:M])
#   else
#     ϕ = sum([elem.wgt[ii]Materials.getϕ(getF(elem,u,ii), elem.mat) for ii in 1:M])
#   end
# end

# %% [raw]
# #let elem = elems[1]
#   u = adiff.D2(zeros(2,4))
#   getϕ(elems[1], u)

# %% [markdown]
# prepare a few arrays needed to start the solution
# - u is the displacement vector, it contains the boundary conditions,
# - ifree is an array of boolean with the same dimension of u, if ifree is true that DoFs is free, otherwise it is constrained, and the value of the constraint is stored in u

# %% [markdown]
# ### Do the compressive branch

# %% [markdown]
# - initialize the displacement vector and the boundary conditions: u is the array with the DoFs, the NaN entries in u are free DoFs, the !NaN entries are the boundary conditions

# %%
@show nNodes, nElems  = length(nodes), length(el_nodes)
@show Δx, Δy          = (xmax-xmin), (ymax-ymin)
;
# Out:
# (nNodes, nElems) = (length(nodes), length(el_nodes)) = (2065, 1956)
# (Δx, Δy) = (xmax - xmin, ymax - ymin) = (5.0, 5.0)

# %%
u                  = fill(NaN, 2, nNodes)
u[:,nid_bndb]     .= 0
u[1,nid_bndt]     .= 0 
u[2,nid_bndt]     .= -ϵn0*Δy

# if !bsheqs u[:,nNodes+1:nNodes+nSHs] .= NaN; end
# if !blheqs u[:,nNodes+nSHs+1:end]    .= NaN; end

if !bfside
    u[1,nid_bndl] .= 0 
    u[1,nid_bndr] .= 0 
end

ifree     = isnan.(u)
icnst     = .!ifree
;

# %% [markdown]
# - this is a preliminary step, for making sure all constranints are initially satisfied and avoid non-convergence on the first step, the result is used as initial condition for the simulation

# %%
u0         = 1e-4Δx*randn(2, nNodes)
u0[icnst] .= 0
unew       = copy(u0)
@time Elements.solvestep!(elems, u0, unew, ifree, bprogress=true, becho=false)
u[ifree] .= unew[ifree]
;
# Out:
# Progress:  Time: 0:00:02 (4 iterations))
#   2.747682 seconds (4.27 M allocations: 8.505 GiB, 6.46% gc time)

# %% [raw]
# ifreeu    = findall(ifree[:]);
# icnstu    = findall(.!ifree[:])
# ;

# %% [raw]
# (Φ,fi,Kt) = Elements.getϕ(elems, u0)
# ;

# %% [markdown]
# ### Do the compressive branch

# %%
N       = 10
#LF_c    = vcat(range(0.0, 0.9, length=2N÷8),
#               range(0.9, 1.0, length=6N÷8))
LF_c    = range(0.0, 1.0, length=N)

allus_c = Elements.solve(elems, u, LF=LF_c, ifree=ifree, 
  bprogress=false, becho=true, bechoi=false)
;
# Out:
# step   1/10, LF=0.000, done in  1 iter, after 0.99 sec.
# step   2/10, LF=0.111, done in  5 iter, after 3.25 sec.
# step   3/10, LF=0.222, done in  3 iter, after 2.34 sec.
# step   4/10, LF=0.333, done in  3 iter, after 2.14 sec.
# step   5/10, LF=0.444, done in  3 iter, after 2.11 sec.
# step   6/10, LF=0.556, done in  3 iter, after 2.36 sec.
# step   7/10, LF=0.667, done in  3 iter, after 2.20 sec.
# step   8/10, LF=0.778, done in  3 iter, after 2.60 sec.
# step   9/10, LF=0.889, done in  2 iter, after 1.56 sec.
# step  10/10, LF=1.000, done in  2 iter, after 1.58 sec.
# completed in 21 seconds

# %%
rf_tot_c = [sum(item[2][2,nid_bndt])   for item in allus_c]
Δu_tot_c = [mean(item[1][2,nid_bndt])  for item in allus_c]
;

# %% [markdown]
# - plot the results

# %%
I1 = get_I1(elems, allus_c[end][1])

cfig = figure()
ax1   = cfig.add_subplot(1,1,1)

plot_model(elems, nodes, alpha=0.05, 
  facecolor=:c, edgecolor=:c, cfig=cfig, ax=ax1)
plot_model(elems, nodes, u = allus_c[end][1], 
  edgecolor=:c, Φ = get_I1(elems, allus_c[end][1]), cfig=cfig, ax=ax1)
title("deformed model - compression")
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject Text(0.5, 1.0, 'deformed model - compression')

# %%
cfig = figure()
ax2   = cfig.add_subplot(1,1,1)
ax2.plot(Δu_tot_c, rf_tot_c)
xlabel("Δu_tot_")
ylabel("rf_tot_c")
title("force-displacement, compressive branch")

cfig.tight_layout(pad=2.0, w_pad=2.0, h_pad=2.0)
;
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ### Do the tensile branch

# %%
u                  = fill(NaN, 2, nNodes)
u[:,nid_bndb]     .= 0
u[1,nid_bndt]     .= 0 
u[2,nid_bndt]     .= ϵn0*Δy

ifree     = isnan.(u)
icnst     = .!ifree
;

# %%
u0         = 1e-4Δx*randn(2, nNodes)
u0[icnst] .= 0
unew       = copy(u0)
@time Elements.solvestep!(elems, u0, unew, ifree, 
                          bprogress=true, becho=false)
u[ifree] .= unew[ifree]
;
# Out:
# Progress:  Time: 0:00:03 (4 iterations)9m
#   3.094969 seconds (4.27 M allocations: 8.505 GiB, 13.10% gc time)

# %%
N       = 10
LF_t    = vcat(range(0.0, 0.9, length=2N÷3),
               range(0.9, 1.0, length=N÷3+1))
println("\n\t starting the tensile branch \n"); flush(stdout)
allus_t = Elements.solve(elems, u, LF=LF_t, ifree=ifree, 
                          bprogress=false, becho=true, bechoi=false)
;
# Out:
# 	 starting the tensile branch
#
# step   1/10, LF=0.000, done in  1 iter, after 1.00 sec.
# step   2/10, LF=0.180, done in  7 iter, after 4.64 sec.
# step   3/10, LF=0.360, done in  4 iter, after 2.82 sec.
# step   4/10, LF=0.540, done in  3 iter, after 2.26 sec.
# step   5/10, LF=0.720, done in  2 iter, after 1.89 sec.
# step   6/10, LF=0.900, done in  2 iter, after 1.69 sec.
# step   7/10, LF=0.900, done in  1 iter, after 1.07 sec.
# step   8/10, LF=0.933, done in  1 iter, after 1.30 sec.
# step   9/10, LF=0.967, done in  2 iter, after 1.59 sec.
# step  10/10, LF=1.000, done in  1 iter, after 1.00 sec.
# completed in 19 seconds

# %%
rf_tot_t = [sum(item[2][2,nid_bndt])   for item in allus_t]
Δu_tot_t = [mean(item[1][2,nid_bndt])  for item in allus_t]
;

# %% [raw]
# JLD.save(sFileName*".jld",
#             "nodes", nodes, "elems", elems,
#             "points", points, "cells", cells, "mat", mat,
#             "nid_bndl", nid_bndl, "nid_bndr", nid_bndr,
#             "nid_bndt", nid_bndt, "nid_bndb", nid_bndb,
#             "allus_t", allus_t, "allus_c", allus_c,
#             "LF_t", LF_t, "LF_c", LF_c,
#             "rf_tot_t", rf_tot_t, "Δu_tot_t", Δu_tot_t,
#             "rf_tot_c", rf_tot_c, "Δu_tot_c", Δu_tot_c,
#             "cntrs_s", cntrs_s, "cntrs_l", cntrs_l,
#             "nid_shx", nid_shx, "nid_lhx", nid_lhx,
#             "Δx", Δx, "Δy", Δy, "nNodes", nNodes, "nElems", nElems,
#             "sMeshFile", sMeshFile, "sFileName", sFileName)
# @printf("results written to %s\n", sFileName); flush(stdout)
# ;

# %%
I1    = get_I1(elems, allus_t[end][1])

cfig  = figure()
ax1   = cfig.add_subplot(1,1,1)

plot_model(elems, nodes, alpha=0.05, 
  facecolor=:c, edgecolor=:c, cfig=cfig, ax=ax1)
plot_model(elems, nodes, u = allus_t[end][1], 
  edgecolor=:c, Φ = get_I1(elems, allus_t[end][1]), cfig=cfig, ax=ax1)
title("deformed model - tensile")
;
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
cfig  = figure()

ax2   = cfig.add_subplot(1,1,1)
ax2.plot(Δu_tot_t, rf_tot_t)
xlabel("Δu_tot")
ylabel("rf_tot")
title("force-displacement, tensile branch")

cfig.tight_layout(pad=2.0, w_pad=2.0, h_pad=2.0)
;
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
PyPlot.figure()
PyPlot.plot(Δu_tot_c, rf_tot_c, Δu_tot_t, rf_tot_t)
PyPlot.xlabel("Δu_tot_")
PyPlot.ylabel("rf_tot_c")
PyPlot.title("force-displacement, total")
;
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
